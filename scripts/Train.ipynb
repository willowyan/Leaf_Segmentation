# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/GreenStand/leaf_seg/Models/
# Out:
# /content/drive/MyDrive/GreenStand/leaf_seg/Models

# %%
# !pip install -r requirements.txt

# %%
# !nohup python -m visdom.server &

# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# !./ngrok authtoken 2ZVFjVei6l0AoxGM1ueUR5lhYhc_7YWoe3e3atJ6EmN13KgCR

# %%
get_ipython().system_raw('./ngrok http 8097 &')
# !curl -s http://localhost:4040/api/tunnels | python3 -c "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://fd22-34-126-91-216.ngrok-free.app

# %%
# !python3 binary_leaf_main.py --model deeplabv3plus_mobilenet --custom_data_path "../leaf_samples" --batch_size 8 --lr 0.05 --total_itrs 3000 --loss_type binary_focal --val_interval 100 --separable_conv --ckpt /content/drive/MyDrive/GreenStand/leaf_seg/Models/pretrained/plantvillage_best.pth #--lr_policy step #--save_val_results #--enable_vis

# %%
# !python3 sagemaker.py --model deeplabv3plus_mobilenet --custom_data_path "../leaf_samples" --batch_size 8 --lr 0.30 --total_itrs 500 --loss_type binary_dice --val_interval 50  --separable_conv #--lr_policy step
